# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("ApplicantRecipientPayments_Template.xlsx")

# %%
df.head()
# Out:
#   UIF Reference Number    Employee Id  Paid Amount Shutdown From Shutdown to  \
# 0            0118003/9  6403055115083      4191.25      1/4/2020   30/4/2020
# 1            0118003/9  6203195245083      4027.45      1/4/2020   30/4/2020
# 2            0118003/9  6812195261088      4027.45      1/4/2020   30/4/2020
# 3            0118003/9  6107165036085      4027.40      1/4/2020   30/4/2020
# 4            0118003/9  6402026192080      4372.55      1/4/2020   30/4/2020
#
#        Bank Name  Account Number  Account Type Received On
# 0        Nedbank      1118458184             1   30/4/2020
# 1        Nedbank      1129815307             1   30/4/2020
# 2   Capitec Bank      1371076896             1   30/4/2020
# 3   Capitec Bank      1314656269             1   30/4/2020
# 4   Capitec Bank      1126670764             1   30/4/2020

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4382 entries, 0 to 4381
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   UIF Reference Number  4382 non-null   object
#  1   Employee Id           4382 non-null   int64
#  2   Paid Amount           4382 non-null   float64
#  3   Shutdown From         4382 non-null   object
#  4   Shutdown to           4382 non-null   object
#  5   Bank Name             4382 non-null   object
#  6   Account Number        4382 non-null   int64
#  7   Account Type          4382 non-null   int64
#  8   Received On           3403 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 308.2+ KB

# %%
uif = pd.read_excel("MTO Forestry Pty Ltd NEXUS UIFREF 0118003_9.xlsx")

# %%
uif.head()
# Out:
#         IDNUMBER Serv_Prov UIFREFERENCENUMBER UIFREFERENCENUMBER2  \
# 0  8503031748085     NEXUS          0118003/9           0118003/9
# 1  6903046034087     NEXUS          0118003/9           0118003/9
# 2  8404155889088     NEXUS          0118003/9           0118003/9
# 3  8304025691088     NEXUS          0118003/9           0118003/9
# 4  8707170198081     NEXUS          0118003/9           0118003/9
#
#                 TRADENAME     IDNUMBER.1 FIRSTNAME   LASTNAME  \
# 0  MTO Forestry (Pty) Ltd  8503031748085   Yolanda  Grootboom
# 1  MTO Forestry (Pty) Ltd  6903046034087    Mncedi     Mqonci
# 2  MTO Forestry (Pty) Ltd  8404155889088    Ayanda     Liwani
# 3  MTO Forestry (Pty) Ltd  8304025691088     Azuka     Ncacha
# 4  MTO Forestry (Pty) Ltd  8707170198081    Amelia   Claassen
#
#     EMPLOYMENTSTARTDATE         SHUTDOWN_FROM  ...        UPDATEDBY  \
# 0  20-OCT-2014 00:00:00  01-MAY-2020 00:00:00  ...  UNBLOCKED_BY_AG
# ...

# %%
uif.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4345 entries, 0 to 4344
# Data columns (total 60 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   IDNUMBER               4345 non-null   int64
#  1   Serv_Prov              4345 non-null   object
#  2   UIFREFERENCENUMBER     4345 non-null   object
#  3   UIFREFERENCENUMBER2    4345 non-null   object
#  4   TRADENAME              4345 non-null   object
#  5   IDNUMBER.1             4345 non-null   int64
#  6   FIRSTNAME              4345 non-null   object
#  7   LASTNAME               4345 non-null   object
#  8   EMPLOYMENTSTARTDATE    4345 non-null   object
#  9   SHUTDOWN_FROM          4345 non-null   object
#  10  SHUTDOWN_TILL          4345 non-null   object
#  11  EMAIL_ADDRESS          4345 non-null   object
#  12  CONTACTNUMBER          4345 non-null   int64
#  13  PAYEREFERENCE          2985 non-null   float64
# ...

# %%
uif['UPDATEDDATE']
# Out:
# 0       19-SEP-2020 05:49:20
# 1       19-SEP-2020 05:49:20
# 2       19-SEP-2020 05:49:20
# 3       19-SEP-2020 05:49:20
# 4       19-SEP-2020 05:49:20
#                 ...
# 4340    07-DEC-2020 11:24:31
# 4341    07-DEC-2020 11:31:03
# 4342    07-DEC-2020 11:22:51
# 4343    27-JAN-2021 23:32:58
# 4344    20-JAN-2021 07:18:48
# Name: UPDATEDDATE, Length: 4345, dtype: object

# %%
import datetime

# %%
uif.UPDATEDDATE = uif.UPDATEDDATE.astype(datetime.time())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-ad9c98349336> in <module>
# ----> 1 uif.UPDATEDDATE = uif.UPDATEDDATE.astype(datetime.time())
#
# c:\users\afrinova1\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# c:\users\afrinova1\appdata\local\programs\python\python39\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# ...

# %%
uif['UPDATEDDATE'] = pd.to_datetime(df['UPDATEDDATE'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\afrinova1\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'UPDATEDDATE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
