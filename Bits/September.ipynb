# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
SepTicket = pd.read_csv("Oct.csv")

# %%
SepTicket.head()
# Out:
#    Ticket Number         Date Created  \
# 0         537589  2020-10-20 08:33:41
# 1         803861  2020-10-19 13:00:10
# 2         295333  2020-10-20 08:09:00
# 3         887741  2020-10-20 09:52:32
# 4         778750  2020-10-20 05:46:03
#
#                                              Subject                From  \
# 0                         New User Request Submitted      REDCap System
# 1                        RE: New REDCap user account  Tumisang Molokwane
# 2                                  FW: REDCAP Access       Susan Meiring
# 3  FW: [REDCap] Survey completed: "Bulk Sponsorsh...      #Fac-HS-RedCap
# 4                         New User Request Submitted    selekane thakadu
#
#                  From Email Priority      Department Help Topic Source  \
# 0  noreply@witsredcap.co.za   Normal  REDCap Support        NaN  Email
# 1    molokwanet@rmpru.co.za   Normal  REDCap Support        NaN  Email
# 2  susan.meiring@nhls.ac.za   Normal  REDCap Support        NaN  Email
# ...

# %%
SepTicket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2578 entries, 0 to 2577
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Ticket Number     2578 non-null   int64
#  1   Date Created      2578 non-null   object
#  2   Subject           2578 non-null   object
#  3   From              2578 non-null   object
#  4   From Email        2578 non-null   object
#  5   Priority          2578 non-null   object
#  6   Department        2578 non-null   object
#  7   Help Topic        958 non-null    object
#  8   Source            2578 non-null   object
#  9   Current Status    2578 non-null   object
#  10  Last Updated      2578 non-null   object
#  11  SLA Due Date      1998 non-null   object
#  12  Due Date          1 non-null      object
#  13  Closed Date       2578 non-null   object
#  14  Overdue           2578 non-null   object
#  15  Merged            2578 non-null   object
# ...

# %%
SepTicket[SepTicket['Help Topic'].isnull()]
# Out:
#       Ticket Number         Date Created  \
# 0            537589  2020-10-20 08:33:41
# 1            803861  2020-10-19 13:00:10
# 2            295333  2020-10-20 08:09:00
# 3            887741  2020-10-20 09:52:32
# 4            778750  2020-10-20 05:46:03
# ...             ...                  ...
# 2573         911121  2020-07-28 15:01:10
# 2574         265662  2020-07-28 15:01:14
# 2575         648786  2020-07-28 15:01:18
# 2576         916806  2020-07-28 15:01:21
# 2577         360009  2020-07-28 14:50:43
#
#                                                 Subject                From  \
# 0                            New User Request Submitted      REDCap System
# 1                           RE: New REDCap user account  Tumisang Molokwane
# 2                                     FW: REDCAP Access       Susan Meiring
# 3     FW: [REDCap] Survey completed: "Bulk Sponsorsh...      #Fac-HS-RedCap
# 4                            New User Request Submitted    selekane thakadu
# ...

# %%
# Regular expression library
import re

sum_email = 0
Split_email = []

for email in SepTicket["From Email"]:
    email = email.split('@')
    Split_email.append(email[1])
    sum_email += 1

# %%
import datetime
from dateutil.relativedelta import relativedelta
from datetime import date

# %%
SepTicket
# Out:
#       Ticket Number         Date Created  \
# 0            537589  2020-10-20 08:33:41
# 1            803861  2020-10-19 13:00:10
# 2            295333  2020-10-20 08:09:00
# 3            887741  2020-10-20 09:52:32
# 4            778750  2020-10-20 05:46:03
# ...             ...                  ...
# 2573         911121  2020-07-28 15:01:10
# 2574         265662  2020-07-28 15:01:14
# 2575         648786  2020-07-28 15:01:18
# 2576         916806  2020-07-28 15:01:21
# 2577         360009  2020-07-28 14:50:43
#
#                                                 Subject                From  \
# 0                            New User Request Submitted      REDCap System
# 1                           RE: New REDCap user account  Tumisang Molokwane
# 2                                     FW: REDCAP Access       Susan Meiring
# 3     FW: [REDCap] Survey completed: "Bulk Sponsorsh...      #Fac-HS-RedCap
# 4                            New User Request Submitted    selekane thakadu
# ...

# %%
Split_email = pd.DataFrame(Split_email)

# %%
Split_email['Email @domains'] = Split_email

# %%
Split_email
# Out:
#                      0    Email @domains
# 0     witsredcap.co.za  witsredcap.co.za
# 1          rmpru.co.za       rmpru.co.za
# 2           nhls.ac.za        nhls.ac.za
# 3           wits.ac.za        wits.ac.za
# 4           wrhi.ac.za        wrhi.ac.za
# ...                ...               ...
# 2573        wits.ac.za        wits.ac.za
# 2574        wits.ac.za        wits.ac.za
# 2575        wits.ac.za        wits.ac.za
# 2576        wits.ac.za        wits.ac.za
# 2577       rmpru.co.za       rmpru.co.za
#
# [2578 rows x 2 columns]

# %%
del Split_email[0]

# %%
SepTicket["Help Topic"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2573    NaN
# 2574    NaN
# 2575    NaN
# 2576    NaN
# 2577    NaN
# Name: Help Topic, Length: 2578, dtype: object

# %%
# Regular expression library
import re

sum_topic = 0
Split_topic = []

for topic in SepTicket["Help Topic"]:
    if(topic == 'NaN'):
        Split_topic.append(topic[1])
    else:
        topic = topic.split('/')
        Split_topic.append(topic[1])
    sum_topic += 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-8841299e5a52> in <module>
#       9         Split_topic.append(topic[1])
#      10     else:
# ---> 11         topic = topic.split('/')
#      12         Split_topic.append(topic[1])
#      13     sum_topic += 1
#
# AttributeError: 'float' object has no attribute 'split'

# %%
SepTicket=SepTicket.assign(Email_Domains = Split_email)

# %%
SepTicket.head()
# Out:
#    Ticket Number         Date Created  \
# 0         537589  2020-10-20 08:33:41
# 1         803861  2020-10-19 13:00:10
# 2         295333  2020-10-20 08:09:00
# 3         887741  2020-10-20 09:52:32
# 4         778750  2020-10-20 05:46:03
#
#                                              Subject                From  \
# 0                         New User Request Submitted      REDCap System
# 1                        RE: New REDCap user account  Tumisang Molokwane
# 2                                  FW: REDCAP Access       Susan Meiring
# 3  FW: [REDCap] Survey completed: "Bulk Sponsorsh...      #Fac-HS-RedCap
# 4                         New User Request Submitted    selekane thakadu
#
#                  From Email Priority      Department Help Topic Source  \
# 0  noreply@witsredcap.co.za   Normal  REDCap Support        NaN  Email
# 1    molokwanet@rmpru.co.za   Normal  REDCap Support        NaN  Email
# 2  susan.meiring@nhls.ac.za   Normal  REDCap Support        NaN  Email
# ...

# %%
Sept = SepTicket[SepTicket["Date Created"] >= '2020-09-01 00:00:00']

# %%
Sept = Sept[Sept["Date Created"] <= '2020-09-31 23:59:59']

# %%
Sept['Closed Date']= pd.to_datetime(Sept['Closed Date']).dt.date

# %%
Sept['Date Created']= pd.to_datetime(Sept['Date Created']).dt.date

# %%
Sept
# Out:
#       Ticket Number Date Created                      Subject  \
# 9            458936   2020-09-28   New User Request Submitted
# 13           240279   2020-09-01   New User Request Submitted
# 14           240279   2020-09-01   New User Request Submitted
# 15           240279   2020-09-01   New User Request Submitted
# 17           497027   2020-09-25   New User Request Submitted
# ...             ...          ...                          ...
# 1462         865685   2020-09-02         Access to my account
# 1463         376027   2020-09-01  FW: REDCap Project Changes
# 1464         955197   2020-09-01                  Redcap link
# 1468         918462   2020-09-01   New User Request Submitted
# 1469         748758   2020-09-01                   logging in
#
#                            From                   From Email Priority  \
# 9                 Meriam Lubisi          theosihle@gmail.com   Normal
# 13             Nonhlanhla Phume  nonhlanhla.phume@nhls.ac.za   Normal
# ...

# %%
Sept.to_csv('Sept_Day_Diff.csv')

# %%
Sept['diff_days'] = abs(Sept['Closed Date'] - Sept['Date Created'])

# %%
Sept
# Out:
#       Ticket Number Date Created                      Subject  \
# 9            458936   2020-09-28   New User Request Submitted
# 13           240279   2020-09-01   New User Request Submitted
# 14           240279   2020-09-01   New User Request Submitted
# 15           240279   2020-09-01   New User Request Submitted
# 17           497027   2020-09-25   New User Request Submitted
# ...             ...          ...                          ...
# 1462         865685   2020-09-02         Access to my account
# 1463         376027   2020-09-01  FW: REDCap Project Changes
# 1464         955197   2020-09-01                  Redcap link
# 1468         918462   2020-09-01   New User Request Submitted
# 1469         748758   2020-09-01                   logging in
#
#                            From                   From Email Priority  \
# 9                 Meriam Lubisi          theosihle@gmail.com   Normal
# 13             Nonhlanhla Phume  nonhlanhla.phume@nhls.ac.za   Normal
# ...

# %%
Sept[Sept['Help Topic'].isnull()]
# Out:
#       Ticket Number Date Created  \
# 23           815073   2020-09-25
# 35           829354   2020-09-25
# 45           471498   2020-09-25
# 46           463899   2020-09-25
# 49           878262   2020-09-25
# ...             ...          ...
# 1453         872114   2020-09-02
# 1454         399058   2020-09-02
# 1461         551934   2020-09-01
# 1462         865685   2020-09-02
# 1463         376027   2020-09-01
#
#                                                 Subject                  From  \
# 23                           New User Request Submitted     Khuthadzo Tambani
# 35                           New User Request Submitted  Gomotsegang Montoedi
# 45                           New User Request Submitted     Welheminah Modisa
# 46                           New User Request Submitted        Nontobeko Xaba
# 49                           New User Request Submitted         Angel Mthanti
# ...                                                 ...                   ...
# ...

# %%
Sept.to_csv('Cleaned_Day_Diff.csv')

# %%
Sept[Sept['diff_days'] > '0 days']
# Out:
#       Ticket Number Date Created  \
# 9            458936   2020-09-28
# 13           240279   2020-09-01
# 14           240279   2020-09-01
# 15           240279   2020-09-01
# 17           497027   2020-09-25
# ...             ...          ...
# 1438         818039   2020-09-01
# 1439         642082   2020-09-01
# 1441         209018   2020-09-01
# 1455         461415   2020-09-01
# 1461         551934   2020-09-01
#
#                                                 Subject              From  \
# 9                            New User Request Submitted     Meriam Lubisi
# 13                           New User Request Submitted  Nonhlanhla Phume
# 14                           New User Request Submitted  Nonhlanhla Phume
# 15                           New User Request Submitted  Nonhlanhla Phume
# 17                           New User Request Submitted         JON ZONDE
# ...                                                 ...               ...
# ...

# %%
SepTicket['Closed Date']= pd.to_datetime(SepTicket['Closed Date'])

# %%
SepTicket['Date Created']= pd.to_datetime(SepTicket['Date Created'])

# %%
SepTicket['diff_days'] = abs(SepTicket['Closed Date'] - SepTicket['Date Created'])
